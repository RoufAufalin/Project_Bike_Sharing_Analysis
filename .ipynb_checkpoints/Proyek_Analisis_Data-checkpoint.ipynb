# %% [markdown]
# # Proyek Analisis Data: [Input Nama Dataset]
# - **Nama:** Rouf Aufalin Al Ghoitsal
# - **Email:** roufaufal01@gmail.com
# - **ID Dicoding:**

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Bagaimanakah tren penyewaan tiap bulan?
# - Apakah ada hubungan antara musim dengan jumlah penyewaan sepeda?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
hours_df = pd.read_csv("data/hour.csv")

hours_df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# **Insight:**
# - Mengumpulkan data yang berasal dari Bike Sharing dataset CSV dan mengkonversinya ke dalam bentuk DataFrame Pandas

# %% [markdown]
# ### Assessing Data

# %%
#memeriksa nilai kosong data perjam
hours_df.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
#memeriksa data duplikat
hours_df.duplicated().sum()
# Out:
# 0

# %%
hours_df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
q25, q75 = np.percentile(hours_df['cnt'], 25), np.percentile(hours_df['cnt'], 75)
iqr = q75 - q25
cut_off = iqr * 1.5
minimum, maximum = q25 - cut_off, q75 + cut_off
 
outliers = [x for x in hours_df['cnt'] if x < minimum or x > maximum]

plt.figure(figsize=(8, 6))
sns.boxplot(x=hours_df['cnt'])
plt.title('Deteksi Outliers pada Kolom CNT')
plt.show()

# %%
hours_df.iloc[outliers]
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 651      652  2011-01-30       1   0     1  11        0        0           0
# 644      645  2011-01-30       1   0     1   3        0        0           0
# 712      713  2011-02-02       1   0     2   1        0        3           1
# 676      677  2011-01-31       1   0     1  12        0        1           1
# 734      735  2011-02-02       1   0     2  23        0        3           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 724      725  2011-02-02       1   0     2  13        0        3           1
# 688      689  2011-02-01       1   0     2   0        0        2           1
# 679      680  2011-01-31       1   0     1  15        0        1           1
# 662      663  2011-01-30       1   0     1  22        0        0           0
# 678      679  2011-01-31       1   0     1  14        0        1           1
#
#      weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 651           1  0.22  0.2727  0.75     0.0000       9          50   59
# 644           1  0.14  0.2121  0.93     0.0000       1           7    8
# 712           3  0.22  0.2273  0.93     0.1940       0           3    3
# 676           2  0.18  0.2121  0.55     0.1045       6          62   68
# 734           1  0.20  0.1667  0.44     0.4478       3          29   32
# ..          ...   ...     ...   ...        ...     ...         ...  ...
# 724           1  0.34  0.3333  0.93     0.1642       1          74   75
# 688           2  0.16  0.1818  0.64     0.1045       2           6    8
# 679           2  0.16  0.1818  0.59     0.1343       3          41   44
# 662           2  0.24  0.2273  0.70     0.1940       2          19   21
# 678           2  0.18  0.1970  0.55     0.1343       1          85   86
#
# [505 rows x 17 columns]

# %% [markdown]
# **Insight:**
# - Tidak ditemukan data kosong
# - Tidak ditemukan data duplikat
# - Berdasarkan pemeriksaan menggunakan IQR tidak ditemukan outliers pada dataframe days
# - Berdasarkan pemeriksaan menggunakan IQR terdapat 505 baris outliers pada dataframe hours

# %% [markdown]
# ### Cleaning Data

# %%
hours_df['dteday'] = pd.to_datetime(days_df['dteday'])
hours_df.head()
# Out:
#    instant     dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1 2011-01-01       1   0     1   0        0        6           0
# 1        2 2011-01-02       1   0     1   1        0        6           0
# 2        3 2011-01-03       1   0     1   2        0        6           0
# 3        4 2011-01-04       1   0     1   3        0        6           0
# 4        5 2011-01-05       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
print(f"Jumlah data sebelum menghapus outlier: {hours_df.shape[0]}")
hours_clean_df = hours_df[(hours_df['cnt'] >= minimum) & (hours_df['cnt'] <= maximum)]

print(f"Jumlah data setelah menghapus outlier: {hours_clean_df.shape[0]}")
# Out:
# Jumlah data sebelum menghapus outlier: 17379
# Jumlah data setelah menghapus outlier: 16874

# %% [markdown]
# **Insight:**
# - Telah mengubah kolom [dteday] menjadi format datetime
# - Telah menghapus data outliers

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %%
hours_clean_df.describe(include='all')
# Out:
#              instant               dteday        season            yr  \
# count   16874.000000                  731  16874.000000  16874.000000
# unique           NaN                  731           NaN           NaN
# top              NaN  2012-08-29 00:00:00           NaN           NaN
# freq             NaN                    1           NaN           NaN
# first            NaN  2011-01-01 00:00:00           NaN           NaN
# last             NaN  2012-12-31 00:00:00           NaN           NaN
# mean     8542.168899                  NaN      2.490399      0.487733
# std      5007.766040                  NaN      1.111966      0.499864
# min         1.000000                  NaN      1.000000      0.000000
# 25%      4219.250000                  NaN      1.000000      0.000000
# 50%      8438.500000                  NaN      2.000000      0.000000
# 75%     12832.750000                  NaN      3.000000      1.000000
# max     17379.000000                  NaN      4.000000      1.000000
#
#                 mnth            hr       holiday       weekday    workingday  \
# count   16874.000000  16874.000000  16874.000000  16874.000000  16874.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# first            NaN           NaN           NaN           NaN           NaN
# last             NaN           NaN           NaN           NaN           NaN
# mean        6.513275     11.458101      0.029513      2.997748      0.678618
# std         3.462438      6.962144      0.169244      2.013054      0.467021
# min         1.000000      0.000000      0.000000      0.000000      0.000000
# 25%         4.000000      5.000000      0.000000      1.000000      0.000000
# 50%         7.000000     11.000000      0.000000      3.000000      1.000000
# 75%        10.000000     18.000000      0.000000      5.000000      1.000000
# max        12.000000     23.000000      1.000000      6.000000      1.000000
#
#           weathersit          temp         atemp           hum     windspeed  \
# count   16874.000000  16874.000000  16874.000000  16874.000000  16874.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# first            NaN           NaN           NaN           NaN           NaN
# last             NaN           NaN           NaN           NaN           NaN
# mean        1.430663      0.492650      0.471970      0.630412      0.189619
# std         0.642689      0.192455      0.171878      0.192600      0.122460
# min         1.000000      0.020000      0.000000      0.000000      0.000000
# 25%         1.000000      0.340000      0.333300      0.480000      0.104500
# 50%         1.000000      0.500000      0.484800      0.630000      0.179100
# 75%         2.000000      0.640000      0.621200      0.790000      0.253700
# max         4.000000      1.000000      1.000000      1.000000      0.850700
#
#               casual    registered           cnt
# count   16874.000000  16874.000000  16874.000000
# unique           NaN           NaN           NaN
# top              NaN           NaN           NaN
# freq             NaN           NaN           NaN
# first            NaN           NaN           NaN
# last             NaN           NaN           NaN
# mean       33.418632    139.291514    172.710146
# std        45.896591    126.052802    155.020918
# min         0.000000      0.000000      1.000000
# 25%         4.000000     32.000000     38.000000
# 50%        15.000000    111.000000    135.000000
# 75%        45.000000    208.000000    265.750000
# max       354.000000    629.000000    642.000000

# %% [markdown]
# **Insight:**
# - Data 'dteday' pada kedua dataframe telah diubah ke dalam format datetime. Data yang ada berasal dari tahun 1 Januari 2011 sampai 31 Desember 2012
# - Setelah outliers dihilangkan rata-rata penyewa sepeta dalam kolom 'cnt' adalah 172.710146

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Bagaimanakah tren penyewaan tiap bulan?

# %%
monthly_count = hours_clean_df.groupby(['yr', 'mnth'])['cnt'].sum().reset_index()
monthly_count['yr'] = monthly_count['yr'].map({0: 2011, 1:2012})

plt.figure(figsize=(10, 5))
sns.lineplot(data=monthly_count, x="mnth", y="cnt", hue="yr", marker="o")

plt.xlabel("Bulan")
plt.ylabel("Total Penyewaan Sepeda")
plt.title("Tren Penyewaan Sepeda per Bulan di Tahun 2011 dan 2012")
plt.xticks(range(1, 13))  
plt.legend(title="Tahun")

plt.show()

# %% [markdown]
# **Insight:**
# - Dapat dilihat bahwa fluktuasi penyewaan perbulan antara tahun 2011 dengan 2012 hampir sama. Pada tahun 2012 terdapat peningkatan jumlah penyewaan dari tahun 2012. Kedua tahun hampir memiliki tren yang sama yaitu terjadi peningkat pada pertengahan tahun dan penurunan pada awal tahun dan akhir tahun

# %% [markdown]
# ### Pertanyaan 2: Apakah ada hubungan antara musim dengan jumlah penyewaan sepeda?

# %%
season_mapping = {
    1: "Spring",
    2: "Summer",
    3: "Fall",
    4: "Winter"
}

season_df = hours_clean_df.groupby('season')['cnt'].sum().reset_index()
season_df['season'] = season_df['season'].map(season_mapping)

plt.figure(figsize=(12,5))
sns.barplot(x=season_df['season'], y=season_df['cnt'], data=season_df, palette="coolwarm")
plt.title('Jumlah Penyewa Tiap Musim')
plt.show()

# %% [markdown]
# **Insight:**
# - Musim yang memiliki jumlah penyewa paling tinggi adalah musim gugur sedangkan yang memiliki jumlah penyewa paling sedikit adalah musim semi

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Conclution pertanyaan 1
# - Conclution pertanyaan 2
